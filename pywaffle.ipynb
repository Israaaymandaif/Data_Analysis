# %%
pip istull pywaffle
import matplotlib.pyplot as plt
from pywaffle import Waffle
# Out:
#   Cell In[2], line 1
#     pip istull pywaffle
#         ^
# SyntaxError: invalid syntax

# %%
data = {'Kevin': 10, 'Joseph': 7, 'Yan': 8, 'Melanie': 2}

# %%
plt.figure(
    FigureClass=Waffle,
    rows=15,
    columns=20,
    values=data,
    legend={'loc': 'upper left', 'bbox_to_anchor': (1.05, 1)},
)
plt.show()
# Out:
# <Waffle size 640x480 with 1 Axes>

# %%
# Data for the waffle chart
data = {'Category 1': 15,
        'Category 2': 30,
        'Category 3': 10,
        'Category 4': 25,
        'Category 5': 20}

# Total number of icons in the waffle chart
total_icons = sum(data.values())

# Create a waffle chart
fig = plt.figure(
    FigureClass=Waffle,
    rows=10,  # Adjust rows to change the height of the waffle chart
    values=data,
    icons='square',  # You can use different icons like 'circle', 'diamond', 'square', 'hexagon', etc.
    colors=["#FF5733", "#FFC300", "#900C3F", "#FF5733", "#C70039"], # Replace with your colors
    legend={'loc': 'upper left', 'bbox_to_anchor': (1, 1)},
    icon_legend=True,
    figsize=(8, 4),  # Adjust figsize to change the width of the waffle chart
    font_size = 18   # Size of the grids
)

# Add a title
plt.title("Basic Waffle Chart Example")

# Display the chart
plt.show()
# Out:
# <Waffle size 800x400 with 1 Axes>
